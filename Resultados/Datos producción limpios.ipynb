# %%
pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    -- ------------------------------------- 7.9/124.9 MB 48.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 18.4/124.9 MB 50.4 MB/s eta 0:00:03
#    --------- ------------------------------ 30.9/124.9 MB 54.6 MB/s eta 0:00:02
#    ------------- -------------------------- 41.7/124.9 MB 53.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 51.1/124.9 MB 50.9 MB/s eta 0:00:02
#    ------------------- -------------------- 59.5/124.9 MB 49.2 MB/s eta 0:00:02
#    ---------------------- ----------------- 70.3/124.9 MB 49.8 MB/s eta 0:00:02
#    ------------------------ --------------- 75.5/124.9 MB 46.8 MB/s eta 0:00:02
#    --------------------------- ------------ 85.2/124.9 MB 46.1 MB/s eta 0:00:01
#    ------------------------------- -------- 97.0/124.9 MB 47.3 MB/s eta 0:00:01
#    ---------------------------------- ---- 109.8/124.9 MB 48.4 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"Datos Completos\Octubre-Abril.csv", sep= "\t", parse_dates=["PoC AB12"], dayfirst=True)
df.columns = ["Date","Pax"]
df = df.iloc[4:,:].reset_index(False)
df = df.drop("index", axis=1)

df["Date"] = pd.to_datetime(df["Date"],  format="%d-%m-%Y %H:%M:%S")
df["Pax"] = pd.to_numeric(df["Pax"])

# %%
df_prod = pd.read_csv(r"C:\Users\Victor\Desktop\Datathon\20240927 Reto UniversityHack 2024\Datos cultivos productivos\Fases producción v02.csv", sep = ";", encoding="ANSI")
df_prod
# Out:
#       LOTE  Orden en el encadenado  LOTE parental  ID Bioreactor  \
# 0    23019                       1            NaN          14615
# 1    23020                       1            NaN          14616
# 2    23021                       1            NaN          13170
# 3    23022                       1            NaN          14614
# 4    23023                       1            NaN          14615
# ..     ...                     ...            ...            ...
# 147  24049                       1            NaN          14617
# 148  24050                       1            NaN          14614
# 149  24051                       1            NaN          13169
# 150  24052                       2        24050.0          14614
# 151  24053                       2        24051.0          13169
#
#        Fecha/hora inicio       Fecha/hora fin Volumen de inóculo utilizado  \
# 0    2023-03-21 07:30:00  2023-03-23 06:30:00                         82,4
# ...

# %%
df_prod["Fecha/hora inicio"] = pd.to_datetime(df_prod["Fecha/hora inicio"],  format="%Y-%m-%d %H:%M:%S")
df_prod["Fecha/hora fin"] = pd.to_datetime(df_prod["Fecha/hora fin"],  format="%Y-%m-%d %H:%M:%S")

# %%
# df_prod["Volumen de inóculo utilizado"] =df_prod["Volumen de inóculo utilizado"].str.replace(",",".")
# df_prod["Turbidez inicio cultivo"] =df_prod["Turbidez inicio cultivo"].str.replace(",",".")
# df_prod["Turbidez fin cultivo"] =df_prod["Turbidez fin cultivo"].str.replace(",",".")
# df_prod["Viabilidad final cultivo"] =df_prod["Viabilidad final cultivo"].str.replace(",",".")
df_prod["Centrifugación 1 turbidez"] =df_prod["Centrifugación 1 turbidez"].str.replace(",",".")
df_prod["Centrifugación 2 turbidez"] =df_prod["Centrifugación 2 turbidez"].str.replace(",",".")
df_prod["Producto 1"] =df_prod["Producto 1"].str.replace(",",".")
df_prod["Producto 2"] =df_prod["Producto 2"].str.replace(",",".")

# %%
df_prod["Viabilidad final cultivo"] =df_prod["Viabilidad final cultivo"].str.upper()

# %%
df_prod.loc[67:67,"Viabilidad final cultivo"] = "1.82E+08"

# %%
# df_prod["Volumen de inóculo utilizado"] = pd.to_numeric(df_prod["Volumen de inóculo utilizado"])
# df_prod["Turbidez inicio cultivo"] = pd.to_numeric(df_prod["Turbidez inicio cultivo"])
# df_prod["Turbidez fin cultivo"] = pd.to_numeric(df_prod["Turbidez fin cultivo"])
# df_prod["Viabilidad final cultivo"] = pd.to_numeric(df_prod["Viabilidad final cultivo"])
df_prod["Centrifugación 1 turbidez"] = pd.to_numeric(df_prod["Centrifugación 1 turbidez"])
df_prod["Centrifugación 2 turbidez"] = pd.to_numeric(df_prod["Centrifugación 2 turbidez"])
df_prod["Producto 1"] = pd.to_numeric(df_prod["Producto 1"])
df_prod["Producto 2"] = pd.to_numeric(df_prod["Producto 2"])

# %%
df_prod.describe()
# Out:
#                LOTE  Orden en el encadenado  LOTE parental  ID Bioreactor  \
# count    152.000000              152.000000      22.000000     152.000000
# mean   23323.151316                1.177632   23571.818182   14120.802632
# min    23019.000000                1.000000   23085.000000   13169.000000
# 25%    23060.750000                1.000000   23112.250000   13170.000000
# 50%    23101.500000                1.000000   23567.500000   14614.000000
# 75%    24003.250000                1.000000   24034.750000   14616.000000
# max    24053.000000                3.000000   24051.000000   14617.000000
# std      416.714932                0.416577     472.657697     687.944111
#
#                    Fecha/hora inicio                 Fecha/hora fin  \
# count                            152                            152
# mean   2023-10-07 01:19:58.421052672  2023-10-09 01:27:14.605263360
# min              2023-03-21 07:30:00            2023-03-23 06:30:00
# ...

# %%
df_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   LOTE                          152 non-null    int64
#  1   Orden en el encadenado        152 non-null    int64
#  2   LOTE parental                 22 non-null     float64
#  3   ID Bioreactor                 152 non-null    int64
#  4   Fecha/hora inicio             152 non-null    datetime64[ns]
#  5   Fecha/hora fin                152 non-null    datetime64[ns]
#  6   Volumen de inóculo utilizado  147 non-null    float64
#  7   Turbidez inicio cultivo       152 non-null    float64
#  8   Turbidez fin cultivo          152 non-null    float64
#  9   Viabilidad final cultivo      152 non-null    float64
#  10  ID Centrífuga                 152 non-null    int64
#  11  Centrifugación 1 turbidez     148 non-null    float64
# ...

# %%
df_prod
# Out:
#       LOTE  Orden en el encadenado  LOTE parental  ID Bioreactor  \
# 0    23019                       1            NaN          14615
# 1    23020                       1            NaN          14616
# 2    23021                       1            NaN          13170
# 3    23022                       1            NaN          14614
# 4    23023                       1            NaN          14615
# ..     ...                     ...            ...            ...
# 147  24049                       1            NaN          14617
# 148  24050                       1            NaN          14614
# 149  24051                       1            NaN          13169
# 150  24052                       2        24050.0          14614
# 151  24053                       2        24051.0          13169
#
#       Fecha/hora inicio      Fecha/hora fin  Volumen de inóculo utilizado  \
# 0   2023-03-21 07:30:00 2023-03-23 06:30:00                          82.4
# ...
