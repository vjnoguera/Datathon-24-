# %%
import pandas as pd
import numpy as np

# %%
df_bio_13169 = pd.read_csv("Datos Biorreactor\Biorreactor de producción\Biorreactor 13169.csv", sep = ";", encoding="ANSI")
df_bio_13169
# Out:
# C:\Users\Victor\AppData\Local\Temp\ipykernel_9680\3422227683.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_bio_13169 = pd.read_csv("Datos Biorreactor\Biorreactor de producción\Biorreactor 13169.csv", sep = ";", encoding="ANSI")
#                       DateTime 13169_FERM0101.Agitation_PV  \
# 0      2023-03-15 00:00:00.000                           0
# 1      2023-03-15 00:15:00.000                           0
# 2      2023-03-15 00:30:00.000                           0
# 3      2023-03-15 00:45:00.000                           0
# 4      2023-03-15 01:00:00.000                           0
# ...                        ...                         ...
# 52409  2024-09-10 23:15:00.000                          80
# 52410  2024-09-10 23:30:00.000                          80
# 52411  2024-09-10 23:45:00.000                          80
# 52412  2024-09-11 00:00:00.000                          80
# ...

# %%
df_bio_13169.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52414 entries, 0 to 52413
# Data columns (total 17 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   DateTime                                 52413 non-null  object
#  1   13169_FERM0101.Agitation_PV              47939 non-null  object
#  2   13169_FERM0101.Air_Sparge_PV             47939 non-null  object
#  3   13169_FERM0101.Biocontainer_Pressure_PV  47945 non-null  object
#  4   13169_FERM0101.DO_1_PV                   47941 non-null  object
#  5   13169_FERM0101.DO_2_PV                   1395 non-null   object
#  6   13169_FERM0101.Gas_Overlay_PV            47939 non-null  object
#  7   13169_FERM0101.Load_Cell_Net_PV          47942 non-null  object
#  8   13169_FERM0101.pH_1_PV                   47940 non-null  object
#  9   13169_FERM0101.pH_2_PV                   47940 non-null  object
# ...

# %%
df_bio_13169["DateTime"] = pd.to_datetime(df_bio_13169["DateTime"])

# %%
df_bio_13169.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52414 entries, 0 to 52413
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Biorreactor                        52414 non-null  int64
#  1   DateTime                           52413 non-null  datetime64[ns]
#  2   FERM0101.Agitation_PV              47939 non-null  object
#  3   FERM0101.Air_Sparge_PV             47939 non-null  object
#  4   FERM0101.Biocontainer_Pressure_PV  47945 non-null  object
#  5   FERM0101.DO_1_PV                   47941 non-null  object
#  6   FERM0101.DO_2_PV                   1395 non-null   object
#  7   FERM0101.Gas_Overlay_PV            47939 non-null  object
#  8   FERM0101.Load_Cell_Net_PV          47942 non-null  object
#  9   FERM0101.pH_1_PV                   47940 non-null  object
#  10  FERM0101.pH_2_PV                   47940 non-null  object
# ...

# %%
df_bio_13169.columns = ['DateTime','FERM0101.Agitation_PV','FERM0101.Air_Sparge_PV','FERM0101.Biocontainer_Pressure_PV','FERM0101.DO_1_PV','FERM0101.DO_2_PV','FERM0101.Gas_Overlay_PV','FERM0101.Load_Cell_Net_PV','FERM0101.pH_1_PV','FERM0101.pH_2_PV','FERM0101.PUMP_1_PV','FERM0101.PUMP_1_TOTAL','FERM0101.PUMP_2_PV','FERM0101.PUMP_2_TOTAL','FERM0101.Single_Use_DO_PV','FERM0101.Single_Use_pH_PV','FERM0101.Temperatura_PV']

# %%
df_bio_13169.insert(0, "Biorreactor", 13169, True)

# %%
df_bio_13169 = df_bio_13169.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)
# Out:
# C:\Users\Victor\AppData\Local\Temp\ipykernel_9680\862673234.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_bio_13169 = df_bio_13169.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)

# %%
df_bio_13169[df_bio_13169.select_dtypes(include=['object']).columns] = df_bio_13169.select_dtypes(include=['object']).apply(lambda col: pd.to_numeric(col, errors='coerce'))

# %%
df_bio_13169.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52414 entries, 0 to 52413
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Biorreactor                        52414 non-null  int64
#  1   DateTime                           52413 non-null  datetime64[ns]
#  2   FERM0101.Agitation_PV              47939 non-null  float64
#  3   FERM0101.Air_Sparge_PV             47939 non-null  float64
#  4   FERM0101.Biocontainer_Pressure_PV  47945 non-null  float64
#  5   FERM0101.DO_1_PV                   47941 non-null  float64
#  6   FERM0101.DO_2_PV                   1395 non-null   float64
#  7   FERM0101.Gas_Overlay_PV            47939 non-null  float64
#  8   FERM0101.Load_Cell_Net_PV          47942 non-null  float64
#  9   FERM0101.pH_1_PV                   47940 non-null  float64
#  10  FERM0101.pH_2_PV                   47940 non-null  float64
# ...

# %%
df_bio_13170 = pd.read_csv("Datos Biorreactor\Biorreactor de producción\Biorreactor 13170.csv", sep = ";", encoding="ANSI")
df_bio_13170
# Out:
# C:\Users\Victor\AppData\Local\Temp\ipykernel_9680\1487615943.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_bio_13170 = pd.read_csv("Datos Biorreactor\Biorreactor de producción\Biorreactor 13170.csv", sep = ";", encoding="ANSI")
#                       DateTime 13170_FERM0101.Agitation_PV  \
# 0      2023-03-15 00:00:00.000                          80
# 1      2023-03-15 00:15:00.000                          80
# 2      2023-03-15 00:30:00.000                          80
# 3      2023-03-15 00:45:00.000                          80
# 4      2023-03-15 01:00:00.000                          80
# ...                        ...                         ...
# 52409  2024-09-10 23:15:00.000                          80
# 52410  2024-09-10 23:30:00.000                          80
# 52411  2024-09-10 23:45:00.000                          80
# 52412  2024-09-11 00:00:00.000                          80
# ...

# %%
df_bio_13170["DateTime"] = pd.to_datetime(df_bio_13170["DateTime"])

# %%
df_bio_13170.columns = ['DateTime','FERM0101.Agitation_PV','FERM0101.Air_Sparge_PV','FERM0101.Biocontainer_Pressure_PV','FERM0101.DO_1_PV','FERM0101.DO_2_PV','FERM0101.Gas_Overlay_PV','FERM0101.Load_Cell_Net_PV','FERM0101.pH_1_PV','FERM0101.pH_2_PV','FERM0101.PUMP_1_PV','FERM0101.PUMP_1_TOTAL','FERM0101.PUMP_2_PV','FERM0101.PUMP_2_TOTAL','FERM0101.Single_Use_DO_PV','FERM0101.Single_Use_pH_PV','FERM0101.Temperatura_PV']
df_bio_13170.insert(0, "Biorreactor", 13170, True)

# %%
df_bio_13170 = df_bio_13170.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)
df_bio_13170[df_bio_13170.select_dtypes(include=['object']).columns] = df_bio_13170.select_dtypes(include=['object']).apply(lambda col: pd.to_numeric(col, errors='coerce'))
# Out:
# C:\Users\Victor\AppData\Local\Temp\ipykernel_9680\1862880137.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_bio_13170 = df_bio_13170.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)

# %%
df_bio_13170.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52414 entries, 0 to 52413
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Biorreactor                        52414 non-null  int64
#  1   DateTime                           52413 non-null  datetime64[ns]
#  2   FERM0101.Agitation_PV              47952 non-null  float64
#  3   FERM0101.Air_Sparge_PV             47952 non-null  float64
#  4   FERM0101.Biocontainer_Pressure_PV  47953 non-null  float64
#  5   FERM0101.DO_1_PV                   47952 non-null  float64
#  6   FERM0101.DO_2_PV                   1624 non-null   float64
#  7   FERM0101.Gas_Overlay_PV            47952 non-null  float64
#  8   FERM0101.Load_Cell_Net_PV          47953 non-null  float64
#  9   FERM0101.pH_1_PV                   47305 non-null  float64
#  10  FERM0101.pH_2_PV                   47953 non-null  float64
# ...

# %%
df_bio_14614 = pd.read_csv("Datos Biorreactor\Biorreactor de producción\Biorreactor 14614.csv", sep = ";", encoding="ANSI")
df_bio_14614
# Out:
#                       DateTime 14614_FERM0101.Agitation_PV  \
# 0      2023-03-15 00:00:00.000                          80
# 1      2023-03-15 00:15:00.000                          80
# 2      2023-03-15 00:30:00.000                          80
# 3      2023-03-15 00:45:00.000                          80
# 4      2023-03-15 01:00:00.000                          80
# ...                        ...                         ...
# 52408  2024-09-10 23:00:00.000                           0
# 52409  2024-09-10 23:15:00.000                           0
# 52410  2024-09-10 23:30:00.000                           0
# 52411  2024-09-10 23:45:00.000                           0
# 52412  2024-09-11 00:00:00.000                           0
#
#       14614_FERM0101.Air_Sparge_PV 14614_FERM0101.Biocontainer_Pressure_PV  \
# 0                                0                             0,572659951
# 1                                0                             0,491942275
# ...

# %%
df_bio_14614["DateTime"] = pd.to_datetime(df_bio_14614["DateTime"])

# %%
df_bio_14614.columns = ['DateTime','FERM0101.Agitation_PV','FERM0101.Air_Sparge_PV','FERM0101.Biocontainer_Pressure_PV','FERM0101.DO_1_PV','FERM0101.DO_2_PV','FERM0101.Gas_Overlay_PV','FERM0101.Load_Cell_Net_PV','FERM0101.pH_1_PV','FERM0101.pH_2_PV','FERM0101.PUMP_1_PV','FERM0101.PUMP_1_TOTAL','FERM0101.PUMP_2_PV','FERM0101.PUMP_2_TOTAL','FERM0101.Single_Use_DO_PV','FERM0101.Single_Use_pH_PV','FERM0101.Temperatura_PV']
df_bio_14614.insert(0, "Biorreactor", 14614, True)

# %%
df_bio_14614 = df_bio_14614.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)
df_bio_14614[df_bio_14614.select_dtypes(include=['object']).columns] = df_bio_14614.select_dtypes(include=['object']).apply(lambda col: pd.to_numeric(col, errors='coerce'))
# Out:
# C:\Users\Victor\AppData\Local\Temp\ipykernel_9680\1948520321.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_bio_14614 = df_bio_14614.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)

# %%
df_bio_14614.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52413 entries, 0 to 52412
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Biorreactor                        52413 non-null  int64
#  1   DateTime                           52413 non-null  datetime64[ns]
#  2   FERM0101.Agitation_PV              47970 non-null  float64
#  3   FERM0101.Air_Sparge_PV             47970 non-null  float64
#  4   FERM0101.Biocontainer_Pressure_PV  47971 non-null  float64
#  5   FERM0101.DO_1_PV                   47970 non-null  float64
#  6   FERM0101.DO_2_PV                   47971 non-null  float64
#  7   FERM0101.Gas_Overlay_PV            47970 non-null  float64
#  8   FERM0101.Load_Cell_Net_PV          47972 non-null  float64
#  9   FERM0101.pH_1_PV                   47972 non-null  float64
#  10  FERM0101.pH_2_PV                   47972 non-null  float64
# ...

# %%
df_bio_14615 = pd.read_csv("Datos Biorreactor\Biorreactor de producción\Biorreactor 14614.csv", sep = ";", encoding="ANSI")
df_bio_14615
# Out:
#                       DateTime 14614_FERM0101.Agitation_PV  \
# 0      2023-03-15 00:00:00.000                          80
# 1      2023-03-15 00:15:00.000                          80
# 2      2023-03-15 00:30:00.000                          80
# 3      2023-03-15 00:45:00.000                          80
# 4      2023-03-15 01:00:00.000                          80
# ...                        ...                         ...
# 52408  2024-09-10 23:00:00.000                           0
# 52409  2024-09-10 23:15:00.000                           0
# 52410  2024-09-10 23:30:00.000                           0
# 52411  2024-09-10 23:45:00.000                           0
# 52412  2024-09-11 00:00:00.000                           0
#
#       14614_FERM0101.Air_Sparge_PV 14614_FERM0101.Biocontainer_Pressure_PV  \
# 0                                0                             0,572659951
# 1                                0                             0,491942275
# ...

# %%
df_bio_14615["DateTime"] = pd.to_datetime(df_bio_14615["DateTime"])

# %%
df_bio_14615.columns = ['DateTime','FERM0101.Agitation_PV','FERM0101.Air_Sparge_PV','FERM0101.Biocontainer_Pressure_PV','FERM0101.DO_1_PV','FERM0101.DO_2_PV','FERM0101.Gas_Overlay_PV','FERM0101.Load_Cell_Net_PV','FERM0101.pH_1_PV','FERM0101.pH_2_PV','FERM0101.PUMP_1_PV','FERM0101.PUMP_1_TOTAL','FERM0101.PUMP_2_PV','FERM0101.PUMP_2_TOTAL','FERM0101.Single_Use_DO_PV','FERM0101.Single_Use_pH_PV','FERM0101.Temperatura_PV']
df_bio_14615.insert(0, "Biorreactor", 14615, True)

# %%
df_bio_14615 = df_bio_14615.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)
df_bio_14615[df_bio_14615.select_dtypes(include=['object']).columns] = df_bio_14615.select_dtypes(include=['object']).apply(lambda col: pd.to_numeric(col, errors='coerce'))
# Out:
# C:\Users\Victor\AppData\Local\Temp\ipykernel_9680\291165483.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_bio_14615 = df_bio_14615.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)

# %%
df_bio_14615.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52413 entries, 0 to 52412
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Biorreactor                        52413 non-null  int64
#  1   DateTime                           52413 non-null  datetime64[ns]
#  2   FERM0101.Agitation_PV              47970 non-null  float64
#  3   FERM0101.Air_Sparge_PV             47970 non-null  float64
#  4   FERM0101.Biocontainer_Pressure_PV  47971 non-null  float64
#  5   FERM0101.DO_1_PV                   47970 non-null  float64
#  6   FERM0101.DO_2_PV                   47971 non-null  float64
#  7   FERM0101.Gas_Overlay_PV            47970 non-null  float64
#  8   FERM0101.Load_Cell_Net_PV          47972 non-null  float64
#  9   FERM0101.pH_1_PV                   47972 non-null  float64
#  10  FERM0101.pH_2_PV                   47972 non-null  float64
# ...

# %%
df_bio_14616 = pd.read_csv("Datos Biorreactor\Biorreactor de producción\Biorreactor 14616.csv", sep = ";", encoding="ANSI")
df_bio_14616
# Out:
# C:\Users\Victor\AppData\Local\Temp\ipykernel_9680\3396542155.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_bio_14616 = pd.read_csv("Datos Biorreactor\Biorreactor de producción\Biorreactor 14616.csv", sep = ";", encoding="ANSI")
#                       DateTime 14616_FERM0101.Agitation_PV  \
# 0      2023-03-15 00:00:00.000                          80
# 1      2023-03-15 00:15:00.000                          80
# 2      2023-03-15 00:30:00.000                          80
# 3      2023-03-15 00:45:00.000                          80
# 4      2023-03-15 01:00:00.000                          80
# ...                        ...                         ...
# 52408  2024-09-10 23:00:00.000                           0
# 52409  2024-09-10 23:15:00.000                           0
# 52410  2024-09-10 23:30:00.000                           0
# 52411  2024-09-10 23:45:00.000                           0
# ...

# %%
df_bio_14616["DateTime"] = pd.to_datetime(df_bio_14616["DateTime"])

# %%
df_bio_14616.columns = ['DateTime','FERM0101.Agitation_PV','FERM0101.Air_Sparge_PV','FERM0101.Biocontainer_Pressure_PV','FERM0101.DO_1_PV','FERM0101.DO_2_PV','FERM0101.Gas_Overlay_PV','FERM0101.Load_Cell_Net_PV','FERM0101.pH_1_PV','FERM0101.pH_2_PV','FERM0101.PUMP_1_PV','FERM0101.PUMP_1_TOTAL','FERM0101.PUMP_2_PV','FERM0101.PUMP_2_TOTAL','FERM0101.Single_Use_DO_PV','FERM0101.Single_Use_pH_PV','FERM0101.Temperatura_PV']
df_bio_14616.insert(0, "Biorreactor", 14616, True)
df_bio_14616 = df_bio_14616.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)
df_bio_14616[df_bio_14616.select_dtypes(include=['object']).columns] = df_bio_14616.select_dtypes(include=['object']).apply(lambda col: pd.to_numeric(col, errors='coerce'))
# Out:
# C:\Users\Victor\AppData\Local\Temp\ipykernel_9680\3779703893.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_bio_14616 = df_bio_14616.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)

# %%
df_bio_14616.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52413 entries, 0 to 52412
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Biorreactor                        52413 non-null  int64
#  1   DateTime                           52413 non-null  datetime64[ns]
#  2   FERM0101.Agitation_PV              48054 non-null  float64
#  3   FERM0101.Air_Sparge_PV             48054 non-null  float64
#  4   FERM0101.Biocontainer_Pressure_PV  48054 non-null  float64
#  5   FERM0101.DO_1_PV                   48054 non-null  float64
#  6   FERM0101.DO_2_PV                   48054 non-null  float64
#  7   FERM0101.Gas_Overlay_PV            48054 non-null  float64
#  8   FERM0101.Load_Cell_Net_PV          48054 non-null  float64
#  9   FERM0101.pH_1_PV                   48054 non-null  float64
#  10  FERM0101.pH_2_PV                   48054 non-null  float64
# ...

# %%
df_bio_14617 = pd.read_csv("Datos Biorreactor\Biorreactor de producción\Biorreactor 14617.csv", sep = ";", encoding="ANSI")
df_bio_14617["DateTime"] = pd.to_datetime(df_bio_14617["DateTime"])
df_bio_14617.columns = ['DateTime','FERM0101.Agitation_PV','FERM0101.Air_Sparge_PV','FERM0101.Biocontainer_Pressure_PV','FERM0101.DO_1_PV','FERM0101.DO_2_PV','FERM0101.Gas_Overlay_PV','FERM0101.Load_Cell_Net_PV','FERM0101.pH_1_PV','FERM0101.pH_2_PV','FERM0101.PUMP_1_PV','FERM0101.PUMP_1_TOTAL','FERM0101.PUMP_2_PV','FERM0101.PUMP_2_TOTAL','FERM0101.Single_Use_DO_PV','FERM0101.Single_Use_pH_PV','FERM0101.Temperatura_PV']
df_bio_14617.insert(0, "Biorreactor", 14617, True)
df_bio_14617 = df_bio_14617.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)
df_bio_14617[df_bio_14617.select_dtypes(include=['object']).columns] = df_bio_14617.select_dtypes(include=['object']).apply(lambda col: pd.to_numeric(col, errors='coerce'))
# Out:
# C:\Users\Victor\AppData\Local\Temp\ipykernel_9680\1705518005.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_bio_14617 = pd.read_csv("Datos Biorreactor\Biorreactor de producción\Biorreactor 14617.csv", sep = ";", encoding="ANSI")
# C:\Users\Victor\AppData\Local\Temp\ipykernel_9680\1705518005.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_bio_14617 = df_bio_14617.applymap(lambda x: x.replace(',', '.') if isinstance(x, str) else x)

# %%
df_bio_14617.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52413 entries, 0 to 52412
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Biorreactor                        52413 non-null  int64
#  1   DateTime                           52413 non-null  datetime64[ns]
#  2   FERM0101.Agitation_PV              47967 non-null  float64
#  3   FERM0101.Air_Sparge_PV             47967 non-null  float64
#  4   FERM0101.Biocontainer_Pressure_PV  47967 non-null  float64
#  5   FERM0101.DO_1_PV                   47967 non-null  float64
#  6   FERM0101.DO_2_PV                   1150 non-null   float64
#  7   FERM0101.Gas_Overlay_PV            47967 non-null  float64
#  8   FERM0101.Load_Cell_Net_PV          47967 non-null  float64
#  9   FERM0101.pH_1_PV                   47967 non-null  float64
#  10  FERM0101.pH_2_PV                   47967 non-null  float64
# ...
